# %%
import warnings
from google.cloud import storage
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# google-cloud-sdk/platform/gsutil/gsutil -m cp -r gs://test-platform-results/pr-logs/directory/pull-ci-openshift-installer-main-e2e-vsphere-ovn-upi .

from pathlib import Path

bucket_name = "test-platform-results"

storage_client = storage.Client(project=None)
bucket = storage_client.get_bucket(bucket_name)
prefix = "pr-logs/directory/pull-ci-openshift-installer-main-e2e-vsphere-ovn-upi"

blobs = bucket.list_blobs(prefix=prefix)

for blob in blobs:
    path_to_job_artifacts = blob.download_as_text()
    # split on the bucket_name and remove the first /
    prefix = (path_to_job_artifacts.split(bucket_name)[-1])[1:-1]

    #print(prefix)
    junit_blobs = bucket.list_blobs(prefix=prefix, match_glob="**junit_e2e*.xml")

    for junit_blob in junit_blobs:
        if "junit_e2e" in junit_blob.name:

            print(Path(junit_blob.name).name)
            print(junit_blob.name)
# Out:
# junit_e2e__20250123-212919.xml
# pr-logs/pull/openshift_installer/9396/pull-ci-openshift-installer-main-e2e-vsphere-ovn-upi-zones/1882523666198040576/artifacts/e2e-vsphere-ovn-upi-zones/openshift-e2e-test/artifacts/junit/junit_e2e__20250123-212919.xml
# junit_e2e__20250124-224805.xml
# pr-logs/pull/openshift_installer/9396/pull-ci-openshift-installer-main-e2e-vsphere-ovn-upi-zones/1882904458766061568/artifacts/e2e-vsphere-ovn-upi-zones/openshift-e2e-test/artifacts/junit/junit_e2e__20250124-224805.xml
# junit_e2e__20250125-055320.xml
# pr-logs/pull/openshift_installer/9396/pull-ci-openshift-installer-main-e2e-vsphere-ovn-upi-zones/1883012016768028672/artifacts/e2e-vsphere-ovn-upi-zones/openshift-e2e-test/artifacts/junit/junit_e2e__20250125-055320.xml
# junit_e2e__20250127-202511.xml
# ...
