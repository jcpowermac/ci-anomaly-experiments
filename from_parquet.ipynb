# %%
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %%
df = pd.read_parquet("installer.parquet")

# %%
df.head()
# Out:
#                                                     2025-01-23 21:29:19  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-01-24 22:48:05  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-01-25 05:53:20  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-01-27 20:25:11  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-02-17 13:21:29  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2024-12-18 03:11:58  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2024-12-18 02:25:04  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2024-12-18 02:46:43  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2024-12-18 02:38:56  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2024-12-18 03:18:26  ...  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0  ...
# [sig-scheduling][Early] The openshift-console d...                  1.0  ...
# [sig-scheduling][Early] The openshift-apiserver...                  1.0  ...
# [sig-scheduling][Early] The openshift-console c...                  1.0  ...
# [sig-ci] [Early] prow job name should match net...                  1.0  ...
#
#                                                     2025-03-24 06:47:12  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 08:07:27  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 09:23:26  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 10:33:51  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 12:30:05  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 13:48:37  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 15:24:31  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 15:31:06  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 15:58:31  \
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
#                                                     2025-03-24 17:17:47
# [sig-instrumentation] Prometheus [apigroup:imag...                  1.0
# [sig-scheduling][Early] The openshift-console d...                  1.0
# [sig-scheduling][Early] The openshift-apiserver...                  1.0
# [sig-scheduling][Early] The openshift-console c...                  1.0
# [sig-ci] [Early] prow job name should match net...                  1.0
#
# [5 rows x 1505 columns]

# %%
df.describe()

summary = df.describe()

# Extract the mean values
mean_values = summary.loc['mean']

#mean_values = mean_values.dropna()
filtered_mean_values = mean_values[mean_values.between(0.1,0.99)]

# Create a Seaborn barplot
plt.figure(figsize=(20, 20))
sns.barplot(x=filtered_mean_values.index, y=filtered_mean_values.values)

# Add labels and title
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Columns')
plt.ylabel('Mean')
plt.title('Mean of Each Column in DataFrame')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1812 entries, [sig-instrumentation] Prometheus [apigroup:image.openshift.io] when installed on the cluster shouldn't report any alerts in firing state apart from Watchdog and AlertmanagerReceiversNotConfigured [Early][apigroup:config.openshift.io] [Skipped:Disconnected] [Suite:openshift/conformance/parallel] to [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support readOnly file specified in the volumeMount [LinuxOnly] [Suite:openshift/conformance/parallel] [Suite:k8s]
# Columns: 1505 entries, 2025-01-23 21:29:19 to 2025-03-24 17:17:47
# dtypes: float64(1505)
# memory usage: 20.8+ MB

# %%
df.T.describe()
# Out:
#        [sig-instrumentation] Prometheus [apigroup:image.openshift.io] when installed on the cluster shouldn't report any alerts in firing state apart from Watchdog and AlertmanagerReceiversNotConfigured [Early][apigroup:config.openshift.io] [Skipped:Disconnected] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.996013
# std                                             0.063035
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-scheduling][Early] The openshift-console downloads pods [apigroup:console.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.996678
# std                                             0.057562
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-scheduling][Early] The openshift-apiserver pods [apigroup:authorization.openshift.io][apigroup:build.openshift.io][apigroup:image.openshift.io][apigroup:project.openshift.io][apigroup:quota.openshift.io][apigroup:route.openshift.io][apigroup:security.openshift.io][apigroup:template.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.995349
# std                                             0.068063
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-scheduling][Early] The openshift-console console pods [apigroup:console.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.996678
# std                                             0.057562
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-ci] [Early] prow job name should match network type [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.997342
# std                                             0.051502
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-scheduling][Early] The openshift-oauth-apiserver pods [apigroup:oauth.openshift.io][apigroup:user.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.997342
# std                                             0.051502
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-scheduling][Early] The openshift-monitoring prometheus-adapter pods [apigroup:monitoring.coreos.com] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.998007
# std                                             0.044617
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-node] Managed cluster record the number of nodes at the beginning of the tests [Early] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.997342
# std                                             0.051502
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-etcd] etcd cluster has the same number of master nodes and voting members from the endpoints configmap [Early][apigroup:config.openshift.io] [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.999336
# std                                             0.025777
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        [sig-arch][Early] CRDs for openshift.io should have subresource.status [Suite:openshift/conformance/parallel]  \
# count                                        1505.000000
# mean                                            0.997342
# std                                             0.051502
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (block volmode)(allowExpansion)] volume-expand should resize volume when PVC is edited while pod is using it [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (block volmode)] provisioning should provision storage with snapshot data source [Feature:VolumeSnapshotDataSource] [Skipped:NoOptionalCapabilities] [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Generic Ephemeral-volume (default fs) (late-binding)] ephemeral should support multiple inline ephemeral volumes [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support existing directory [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Generic Ephemeral-volume (default fs) (immediate-binding)] ephemeral should support expansion of pvcs created for ephemeral pvcs [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] provisioning should mount multiple PV pointing to the same storage on the same node [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support file as subpath [LinuxOnly] [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Generic Ephemeral-volume (default fs) (late-binding)] ephemeral should support expansion of pvcs created for ephemeral pvcs [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support readOnly directory specified in the volumeMount [Suite:openshift/conformance/parallel] [Suite:k8s]  \
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support readOnly file specified in the volumeMount [LinuxOnly] [Suite:openshift/conformance/parallel] [Suite:k8s]
# count                                               11.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
# [8 rows x 1812 columns]

# %%
df.T.describe().loc["mean"] < 0.98
# Out:
# [sig-instrumentation] Prometheus [apigroup:image.openshift.io] when installed on the cluster shouldn't report any alerts in firing state apart from Watchdog and AlertmanagerReceiversNotConfigured [Early][apigroup:config.openshift.io] [Skipped:Disconnected] [Suite:openshift/conformance/parallel]                                                                                                                        False
# [sig-scheduling][Early] The openshift-console downloads pods [apigroup:console.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]                                                                                                                                                                                                                     False
# [sig-scheduling][Early] The openshift-apiserver pods [apigroup:authorization.openshift.io][apigroup:build.openshift.io][apigroup:image.openshift.io][apigroup:project.openshift.io][apigroup:quota.openshift.io][apigroup:route.openshift.io][apigroup:security.openshift.io][apigroup:template.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]    False
# [sig-scheduling][Early] The openshift-console console pods [apigroup:console.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]                                                                                                                                                                                                                       False
# [sig-ci] [Early] prow job name should match network type [Suite:openshift/conformance/parallel]                                                                                                                                                                                                                                                                                                                                False
#                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] provisioning should mount multiple PV pointing to the same storage on the same node [Suite:openshift/conformance/parallel] [Suite:k8s]                                                                                                                                          False
# [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support file as subpath [LinuxOnly] [Suite:openshift/conformance/parallel] [Suite:k8s]                                                                                                                                                                           False
# [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Generic Ephemeral-volume (default fs) (late-binding)] ephemeral should support expansion of pvcs created for ephemeral pvcs [Suite:openshift/conformance/parallel] [Suite:k8s]                                                                                                                           False
# [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support readOnly directory specified in the volumeMount [Suite:openshift/conformance/parallel] [Suite:k8s]                                                                                                                                                       False
# [sig-storage] OCP CSI Volumes [Driver: csi-hostpath-groupsnapshot] [OCPFeatureGate:VolumeGroupSnapshot] [Testpattern: Dynamic PV (default fs)] subPath should support readOnly file specified in the volumeMount [LinuxOnly] [Suite:openshift/conformance/parallel] [Suite:k8s]                                                                                                                                                False
# Name: mean, Length: 1812, dtype: bool

# %%
# chatgpt!
summary = df.T.describe()

# Extract the mean values
mean_values = summary.loc['mean']

mean_values = mean_values.dropna()
filtered_mean_values = mean_values[mean_values.between(0.1,0.98)]

# Create a Seaborn barplot
plt.figure(figsize=(20, 20))
sns.barplot(y=filtered_mean_values.index, x=filtered_mean_values.values, orient='h')

# Add labels and title
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Columns')
plt.ylabel('Mean')
plt.title('Mean of Each Column in DataFrame')

# Show the plot
plt.tight_layout()
plt.show()

# %%
filtered_mean_values
# Out:
# [sig-scheduling][Early] The HAProxy router pods [apigroup:route.openshift.io] should be scheduled on different nodes [Skipped:SingleReplicaTopology] [Suite:openshift/conformance/parallel]                         0.944186
# [sig-arch][Early] Managed cluster should [apigroup:config.openshift.io] start all core operators [Skipped:Disconnected] [Suite:openshift/conformance/parallel]                                                      0.939535
# [sig-network] Conntrack should be able to preserve UDP traffic when server pod cycles for a NodePort service [Suite:openshift/conformance/parallel] [Suite:k8s]                                                     0.979402
# [sig-network] Services should be rejected for evicted pods (no endpoints exist) [Suite:openshift/conformance/parallel] [Suite:k8s]                                                                                  0.940864
# [sig-instrumentation] Metrics should grab all metrics from kubelet /metrics/resource endpoint [Suite:openshift/conformance/parallel] [Suite:k8s]                                                                    0.920930
#                                                                                                                                                                                                                       ...
# [sig-apps][apigroup:apps.openshift.io] Evaluate DaemonSet placement in HighlyAvailableArbiterMode topology should not create a DaemonSet on the Arbiter node [Suite:openshift/conformance/parallel]                 0.000000
# [sig-apps][apigroup:apps.openshift.io] Deployments on HighlyAvailableArbiterMode topology should be created on arbiter nodes when arbiter node is selected [Suite:openshift/conformance/parallel]                   0.000000
# [sig-node][apigroup:config.openshift.io] expected Master and Arbiter node counts Should validate that there are Master and Arbiter nodes as specified in the cluster [Suite:openshift/conformance/parallel]         0.000000
# [sig-network][OCPFeatureGate:DNSNameResolver][Feature:EgressFirewall] when using openshift ovn-kubernetes should ensure egressfirewall with wildcard dns rules is created [Suite:openshift/conformance/parallel]    0.838095
# [sig-instrumentation][OCPFeatureGate:MetricsCollectionProfiles] The collection profiles feature-set in a homogeneous minimal environment, should hide default metrics [Suite:openshift/conformance/parallel]        0.697674
# Name: mean, Length: 139, dtype: float64
